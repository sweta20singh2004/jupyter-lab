# %% [markdown]
# # DATABASE CONNECTIVITY

# %%
conda install mysql-connector-python
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Start

# %%
import mysql.connector
import pandas as pd 
import os

# %%
import mysql.connector
import os

# Retrieve MySQL connection credentials from environment variables
mysql_user = 'jovyan'
mysql_password = 'password'
mysql_database = 'hanisntsolo'
# MySQL database connection configuration
mysql_config = {
    'host': '180.233.120.124',
    'port': 18033,
    'user': mysql_user,
    'password': mysql_password,
    'database': mysql_database
}

try:
    # Connect to MySQL database
    conn = mysql.connector.connect(**mysql_config)
    print("Connected to MySQL database")

    # Perform database operations here

except mysql.connector.Error as err:
    print("Error connecting to MySQL:", err)

finally:
    # Close the database connection
    if 'conn' in locals() and conn.is_connected():
        conn.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL database
# MySQL connection closed

# %% [markdown]
# ## Install JupySQL & MySQL Client

# %% [markdown]
# ### JUPYSQL

# %%
conda install jupysql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backoff-2.2.1              |     pyhd8ed1ab_0          17 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     jupysql-0.10.9             |     pyhd8ed1ab_0          78 KB  conda-forge
#     jupysql-plugin-0.4.3       |     pyhd8ed1ab_0         215 KB  conda-forge
#     monotonic-1.5              |     pyhd8ed1ab_1          13 KB  conda-forge
#     ploomber-core-0.2.25       |     pyhd8ed1ab_0          29 KB  conda-forge
#     posthog-3.5.0              |     pyhd8ed1ab_1          39 KB  conda-forge
#     prettytable-3.10.0         |     pyhd8ed1ab_0          29 KB  conda-forge
#     sqlglot-24.1.0             |     pyhd8ed1ab_0         264 KB  conda-forge
#     sqlparse-0.5.0             |     pyhd8ed1ab_0          39 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         807 KB
#
# The following NEW packages will be INSTALLED:
#
#   backoff            conda-forge/noarch::backoff-2.2.1-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   jupysql            conda-forge/noarch::jupysql-0.10.9-pyhd8ed1ab_0
#   jupysql-plugin     conda-forge/noarch::jupysql-plugin-0.4.3-pyhd8ed1ab_0
#   monotonic          conda-forge/noarch::monotonic-1.5-pyhd8ed1ab_1
#   ploomber-core      conda-forge/noarch::ploomber-core-0.2.25-pyhd8ed1ab_0
#   posthog            conda-forge/noarch::posthog-3.5.0-pyhd8ed1ab_1
#   prettytable        conda-forge/noarch::prettytable-3.10.0-pyhd8ed1ab_0
#   sqlglot            conda-forge/noarch::sqlglot-24.1.0-pyhd8ed1ab_0
#   sqlparse           conda-forge/noarch::sqlparse-0.5.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# sqlglot-24.1.0       | 264 KB    |                                       |   0%
# monotonic-1.5        | 13 KB     |                                       |   0%
#
# posthog-3.5.0        | 39 KB     |                                       |   0%
#
#
# backoff-2.2.1        | 17 KB     |                                       |   0%
#
#
#
# ploomber-core-0.2.25 | 29 KB     |                                       |   0%
#
#
#
#
# prettytable-3.10.0   | 29 KB     |                                       |   0%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     |                                       |   0%
#
#
#
#
#
#
# jupysql-0.10.9       | 78 KB     |                                       |   0%
#
#
#
#
#
#
#
# jupysql-plugin-0.4.3 | 215 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# click-8.1.7          | 82 KB     |                                       |   0%
#
#
# backoff-2.2.1        | 17 KB     | ##################################6   |  94%
#
#
# backoff-2.2.1        | 17 KB     | ##################################### | 100%
# monotonic-1.5        | 13 KB     | ##################################### | 100%
# monotonic-1.5        | 13 KB     | ##################################### | 100%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     | ###############                       |  41%
#
# posthog-3.5.0        | 39 KB     | ###############3                      |  41%
#
#
#
#
# sqlglot-24.1.0       | 264 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
# click-8.1.7          | 82 KB     | #######1                              |  19%
#
#
#
#
# prettytable-3.10.0   | 29 KB     | ##################################### | 100%
#
#
#
#
# prettytable-3.10.0   | 29 KB     | ##################################### | 100%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     | ##################################### | 100%
#
# posthog-3.5.0        | 39 KB     | ##################################### | 100%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     | ##################################### | 100%
#
# posthog-3.5.0        | 39 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# click-8.1.7          | 82 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# sqlglot-24.1.0       | 264 KB    | ######################3               |  60%
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ####################5                 |  55%
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ##################################### | 100%
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# sqlglot-24.1.0       | 264 KB    | ##################################### | 100%
#
#
#
#
#
#
# jupysql-0.10.9       | 78 KB     | #######5                              |  20%
#
#
#
#
#
#
#
# jupysql-plugin-0.4.3 | 215 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# jupysql-plugin-0.4.3 | 215 KB    | ##################################### | 100%
#
#
#
#
#
#
# jupysql-0.10.9       | 78 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda upgrade jupysql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alembic-1.13.1             |     pyhd8ed1ab_1         155 KB  conda-forge
#     anyio-4.3.0                |     pyhd8ed1ab_0         100 KB  conda-forge
#     asttokens-2.4.1            |     pyhd8ed1ab_0          28 KB  conda-forge
#     attrs-23.2.0               |     pyh71513ae_0          53 KB  conda-forge
#     babel-2.14.0               |     pyhd8ed1ab_0         7.3 MB  conda-forge
#     beautifulsoup4-4.12.3      |     pyha770c72_0         115 KB  conda-forge
#     blinker-1.8.2              |     pyhd8ed1ab_0          14 KB  conda-forge
#     boltons-24.0.0             |     pyhd8ed1ab_0         291 KB  conda-forge
#     bzip2-1.0.8                |       hd590300_5         248 KB  conda-forge
#     c-ares-1.28.1              |       hd590300_0         165 KB  conda-forge
#     charset-normalizer-3.3.2   |     pyhd8ed1ab_0          46 KB  conda-forge
#     comm-0.2.2                 |     pyhd8ed1ab_0          12 KB  conda-forge
#     configurable-http-proxy-4.6.1|       h92b4e83_0         1.3 MB  conda-forge
#     cryptography-42.0.7        |  py311h4a61cc7_0         1.9 MB  conda-forge
#     debugpy-1.8.1              |  py311hb755f60_0         2.2 MB  conda-forge
#     exceptiongroup-1.2.0       |     pyhd8ed1ab_2          20 KB  conda-forge
#     executing-2.0.1            |     pyhd8ed1ab_0          27 KB  conda-forge
#     fmt-10.2.1                 |       h00ab1b0_0         189 KB  conda-forge
#     greenlet-3.0.3             |  py311hb755f60_0         231 KB  conda-forge
#     idna-3.7                   |     pyhd8ed1ab_0          51 KB  conda-forge
#     importlib-metadata-7.1.0   |     pyha770c72_0          26 KB  conda-forge
#     importlib_metadata-7.1.0   |       hd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.4.0  |     pyhd8ed1ab_0          32 KB  conda-forge
#     ipykernel-6.29.3           |     pyhd33586a_0         116 KB  conda-forge
#     ipython-8.25.0             |     pyh707e725_0         585 KB  conda-forge
#     ipython_genutils-0.2.0     |     pyhd8ed1ab_1          27 KB  conda-forge
#     jinja2-3.1.4               |     pyhd8ed1ab_0         109 KB  conda-forge
#     json5-0.9.25               |     pyhd8ed1ab_0          27 KB  conda-forge
#     jsonschema-4.22.0          |     pyhd8ed1ab_0          72 KB  conda-forge
#     jsonschema-specifications-2023.12.1|     pyhd8ed1ab_0          16 KB  conda-forge
#     jsonschema-with-format-nongpl-4.22.0|     pyhd8ed1ab_0           7 KB  conda-forge
#     jupyter-lsp-2.2.5          |     pyhd8ed1ab_0          54 KB  conda-forge
#     jupyter_client-8.6.2       |     pyhd8ed1ab_0         104 KB  conda-forge
#     jupyter_events-0.10.0      |     pyhd8ed1ab_0          21 KB  conda-forge
#     jupyter_server-2.14.1      |     pyhd8ed1ab_0         317 KB  conda-forge
#     jupyter_server_terminals-0.5.3|     pyhd8ed1ab_0          19 KB  conda-forge
#     jupyterlab_pygments-0.3.0  |     pyhd8ed1ab_0          18 KB  conda-forge
#     jupyterlab_server-2.27.2   |     pyhd8ed1ab_0          48 KB  conda-forge
#     ld_impl_linux-64-2.40      |       hf3520f5_1         691 KB  conda-forge
#     libev-4.33                 |       hd590300_2         110 KB  conda-forge
#     libexpat-2.6.2             |       h59595ed_0          72 KB  conda-forge
#     libgcc-ng-13.2.0           |       h77fa898_7         758 KB  conda-forge
#     libgomp-13.2.0             |       h77fa898_7         412 KB  conda-forge
#     libiconv-1.17              |       hd590300_2         689 KB  conda-forge
#     libnghttp2-1.58.0          |       h47da74e_1         617 KB  conda-forge
#     libsolv-0.7.29             |       ha6fb4c9_0         460 KB  conda-forge
#     libsqlite-3.45.3           |       h2797004_0         840 KB  conda-forge
#     libstdcxx-ng-13.2.0        |       hc0a3c3a_7         3.7 MB  conda-forge
#     libuv-1.48.0               |       hd590300_0         879 KB  conda-forge
#     libxml2-2.11.6             |       h232c23b_0         689 KB  conda-forge
#     libzlib-1.2.13             |       h4ab18f5_6          60 KB  conda-forge
#     lzo-2.10                   |    hd590300_1001         167 KB  conda-forge
#     mako-1.3.5                 |     pyhd8ed1ab_0          66 KB  conda-forge
#     markupsafe-2.1.5           |  py311h459d7ec_0          27 KB  conda-forge
#     matplotlib-inline-0.1.7    |     pyhd8ed1ab_0          14 KB  conda-forge
#     mistune-3.0.2              |     pyhd8ed1ab_0          64 KB  conda-forge
#     nbclient-0.10.0            |     pyhd8ed1ab_0          27 KB  conda-forge
#     nbconvert-7.16.4           |       hd8ed1ab_0           8 KB  conda-forge
#     nbconvert-core-7.16.4      |     pyhd8ed1ab_0         185 KB  conda-forge
#     nbconvert-pandoc-7.16.4    |       hd8ed1ab_0           8 KB  conda-forge
#     nbformat-5.10.4            |     pyhd8ed1ab_0          99 KB  conda-forge
#     ncurses-6.5                |       h59595ed_0         867 KB  conda-forge
#     nest-asyncio-1.6.0         |     pyhd8ed1ab_0          11 KB  conda-forge
#     nodejs-20.12.2             |       hb753e55_0        16.4 MB  conda-forge
#     notebook-shim-0.2.4        |     pyhd8ed1ab_0          16 KB  conda-forge
#     overrides-7.7.0            |     pyhd8ed1ab_0          30 KB  conda-forge
#     packaging-24.0             |     pyhd8ed1ab_0          49 KB  conda-forge
#     pandoc-3.2                 |       ha770c72_0        20.1 MB  conda-forge
#     parso-0.8.4                |     pyhd8ed1ab_0          73 KB  conda-forge
#     pexpect-4.9.0              |     pyhd8ed1ab_0          52 KB  conda-forge
#     platformdirs-4.2.2         |     pyhd8ed1ab_0          20 KB  conda-forge
#     pluggy-1.5.0               |     pyhd8ed1ab_0          23 KB  conda-forge
#     prometheus_client-0.20.0   |     pyhd8ed1ab_0          48 KB  conda-forge
#     prompt-toolkit-3.0.42      |     pyha770c72_0         264 KB  conda-forge
#     psutil-5.9.8               |  py311h459d7ec_0         494 KB  conda-forge
#     pycparser-2.22             |     pyhd8ed1ab_0         103 KB  conda-forge
#     pygments-2.18.0            |     pyhd8ed1ab_0         859 KB  conda-forge
#     pyjwt-2.8.0                |     pyhd8ed1ab_1          24 KB  conda-forge
#     pyopenssl-24.0.0           |     pyhd8ed1ab_0         124 KB  conda-forge
#     python-dateutil-2.9.0      |     pyhd8ed1ab_0         218 KB  conda-forge
#     python-fastjsonschema-2.19.1|     pyhd8ed1ab_0         220 KB  conda-forge
#     pytz-2024.1                |     pyhd8ed1ab_0         184 KB  conda-forge
#     pyzmq-26.0.3               |  py311h08a0b41_0         464 KB  conda-forge
#     referencing-0.35.1         |     pyhd8ed1ab_0          41 KB  conda-forge
#     reproc-14.2.4.post0        |       hd590300_1          33 KB  conda-forge
#     reproc-cpp-14.2.4.post0    |       h59595ed_1          25 KB  conda-forge
#     requests-2.32.3            |     pyhd8ed1ab_0          57 KB  conda-forge
#     rpds-py-0.18.1             |  py311h5ecf98a_0         899 KB  conda-forge
#     ruamel.yaml-0.17.40        |  py311h459d7ec_0         269 KB  conda-forge
#     ruamel.yaml.clib-0.2.8     |  py311h459d7ec_0         133 KB  conda-forge
#     send2trash-1.8.3           |     pyh0d859eb_0          22 KB  conda-forge
#     setuptools-70.0.0          |     pyhd8ed1ab_0         472 KB  conda-forge
#     sniffio-1.3.1              |     pyhd8ed1ab_0          15 KB  conda-forge
#     sqlalchemy-2.0.30          |  py311h331c9d8_0         3.4 MB  conda-forge
#     terminado-0.18.1           |     pyh0d859eb_0          22 KB  conda-forge
#     tinycss2-1.3.0             |     pyhd8ed1ab_0          25 KB  conda-forge
#     tk-8.6.13                  |noxft_h4845f30_101         3.2 MB  conda-forge
#     tornado-6.4                |  py311h459d7ec_0         833 KB  conda-forge
#     tqdm-4.66.4                |     pyhd8ed1ab_0          87 KB  conda-forge
#     traitlets-5.14.3           |     pyhd8ed1ab_0         108 KB  conda-forge
#     types-python-dateutil-2.9.0.20240316|     pyhd8ed1ab_0          21 KB  conda-forge
#     typing-extensions-4.12.1   |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.12.1   |     pyha770c72_0          39 KB  conda-forge
#     tzdata-2024a               |       h0c530f3_0         117 KB  conda-forge
#     urllib3-2.2.1              |     pyhd8ed1ab_0          92 KB  conda-forge
#     wcwidth-0.2.13             |     pyhd8ed1ab_0          32 KB  conda-forge
#     websocket-client-1.8.0     |     pyhd8ed1ab_0          46 KB  conda-forge
#     zeromq-4.3.5               |       h75354e8_4         345 KB  conda-forge
#     zlib-1.2.13                |       h4ab18f5_6          91 KB  conda-forge
#     zstandard-0.22.0           |  py311haa97af0_0         406 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        77.6 MB
#
# The following packages will be REMOVED:
#
#   backcall-0.2.0-pyh9f0ad1d_0
#   backports-1.0-pyhd8ed1ab_3
#   backports.functools_lru_cache-1.6.5-pyhd8ed1ab_0
#   gmp-6.2.1-h58526e2_0
#   pip-23.3-pyhd8ed1ab_0
#   prompt_toolkit-3.0.39-hd8ed1ab_0
#   wheel-0.41.2-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   alembic                               1.12.0-pyhd8ed1ab_0 --> 1.13.1-pyhd8ed1ab_1
#   anyio                                  4.0.0-pyhd8ed1ab_0 --> 4.3.0-pyhd8ed1ab_0
#   asttokens                              2.4.0-pyhd8ed1ab_0 --> 2.4.1-pyhd8ed1ab_0
#   attrs                                 23.1.0-pyh71513ae_1 --> 23.2.0-pyh71513ae_0
#   babel                                 2.13.0-pyhd8ed1ab_0 --> 2.14.0-pyhd8ed1ab_0
#   beautifulsoup4                        4.12.2-pyha770c72_0 --> 4.12.3-pyha770c72_0
#   blinker                                1.6.3-pyhd8ed1ab_0 --> 1.8.2-pyhd8ed1ab_0
#   boltons                               23.0.0-pyhd8ed1ab_0 --> 24.0.0-pyhd8ed1ab_0
#   bzip2                                    1.0.8-h7f98852_4 --> 1.0.8-hd590300_5
#   c-ares                                  1.20.1-hd590300_0 --> 1.28.1-hd590300_0
#   charset-normalizer                     3.3.0-pyhd8ed1ab_0 --> 3.3.2-pyhd8ed1ab_0
#   comm                                   0.1.4-pyhd8ed1ab_0 --> 0.2.2-pyhd8ed1ab_0
#   configurable-http~                       4.5.6-h92b4e83_1 --> 4.6.1-h92b4e83_0
#   cryptography                       41.0.4-py311h63ff55d_0 --> 42.0.7-py311h4a61cc7_0
#   debugpy                             1.8.0-py311hb755f60_1 --> 1.8.1-py311hb755f60_0
#   exceptiongroup                         1.1.3-pyhd8ed1ab_0 --> 1.2.0-pyhd8ed1ab_2
#   executing                              1.2.0-pyhd8ed1ab_0 --> 2.0.1-pyhd8ed1ab_0
#   fmt                                     10.1.1-h00ab1b0_0 --> 10.2.1-h00ab1b0_0
#   greenlet                            3.0.0-py311hb755f60_1 --> 3.0.3-py311hb755f60_0
#   idna                                     3.4-pyhd8ed1ab_0 --> 3.7-pyhd8ed1ab_0
#   importlib-metadata                     6.8.0-pyha770c72_0 --> 7.1.0-pyha770c72_0
#   importlib_metadata                       6.8.0-hd8ed1ab_0 --> 7.1.0-hd8ed1ab_0
#   importlib_resourc~                     6.1.0-pyhd8ed1ab_0 --> 6.4.0-pyhd8ed1ab_0
#   ipykernel                             6.25.2-pyh2140261_0 --> 6.29.3-pyhd33586a_0
#   ipython                               8.16.1-pyh0d859eb_0 --> 8.25.0-pyh707e725_0
#   jinja2                                 3.1.2-pyhd8ed1ab_1 --> 3.1.4-pyhd8ed1ab_0
#   json5                                 0.9.14-pyhd8ed1ab_0 --> 0.9.25-pyhd8ed1ab_0
#   jsonschema                            4.19.1-pyhd8ed1ab_0 --> 4.22.0-pyhd8ed1ab_0
#   jsonschema-specif~                  2023.7.1-pyhd8ed1ab_0 --> 2023.12.1-pyhd8ed1ab_0
#   jsonschema-with-f~                    4.19.1-pyhd8ed1ab_0 --> 4.22.0-pyhd8ed1ab_0
#   jupyter-lsp                            2.2.0-pyhd8ed1ab_0 --> 2.2.5-pyhd8ed1ab_0
#   jupyter_client                         8.4.0-pyhd8ed1ab_0 --> 8.6.2-pyhd8ed1ab_0
#   jupyter_events                         0.8.0-pyhd8ed1ab_0 --> 0.10.0-pyhd8ed1ab_0
#   jupyter_server                         2.8.0-pyhd8ed1ab_0 --> 2.14.1-pyhd8ed1ab_0
#   jupyter_server_te~                     0.4.4-pyhd8ed1ab_1 --> 0.5.3-pyhd8ed1ab_0
#   jupyterlab_pygmen~                     0.2.2-pyhd8ed1ab_0 --> 0.3.0-pyhd8ed1ab_0
#   jupyterlab_server                     2.25.0-pyhd8ed1ab_0 --> 2.27.2-pyhd8ed1ab_0
#   ld_impl_linux-64                          2.40-h41732ed_0 --> 2.40-hf3520f5_1
#   libev                                     4.33-h516909a_1 --> 4.33-hd590300_2
#   libexpat                                 2.5.0-hcb278e6_1 --> 2.6.2-h59595ed_0
#   libgcc-ng                               13.2.0-h807b86a_2 --> 13.2.0-h77fa898_7
#   libgomp                                 13.2.0-h807b86a_2 --> 13.2.0-h77fa898_7
#   libiconv                                  1.17-h166bdaf_0 --> 1.17-hd590300_2
#   libnghttp2                              1.52.0-h61bc06f_0 --> 1.58.0-h47da74e_1
#   libsolv                                 0.7.25-hfc55251_0 --> 0.7.29-ha6fb4c9_0
#   libsqlite                               3.43.2-h2797004_0 --> 3.45.3-h2797004_0
#   libstdcxx-ng                            13.2.0-h7e041cc_2 --> 13.2.0-hc0a3c3a_7
#   libuv                                   1.46.0-hd590300_0 --> 1.48.0-hd590300_0
#   libxml2                                 2.11.5-h232c23b_1 --> 2.11.6-h232c23b_0
#   libzlib                                 1.2.13-hd590300_5 --> 1.2.13-h4ab18f5_6
#   lzo                                    2.10-h516909a_1000 --> 2.10-hd590300_1001
#   mako                                   1.2.4-pyhd8ed1ab_0 --> 1.3.5-pyhd8ed1ab_0
#   markupsafe                          2.1.3-py311h459d7ec_1 --> 2.1.5-py311h459d7ec_0
#   matplotlib-inline                      0.1.6-pyhd8ed1ab_0 --> 0.1.7-pyhd8ed1ab_0
#   mistune                                3.0.1-pyhd8ed1ab_0 --> 3.0.2-pyhd8ed1ab_0
#   nbclient                               0.8.0-pyhd8ed1ab_0 --> 0.10.0-pyhd8ed1ab_0
#   nbconvert                              7.9.2-pyhd8ed1ab_0 --> 7.16.4-hd8ed1ab_0
#   nbconvert-core                         7.9.2-pyhd8ed1ab_0 --> 7.16.4-pyhd8ed1ab_0
#   nbconvert-pandoc                       7.9.2-pyhd8ed1ab_0 --> 7.16.4-hd8ed1ab_0
#   nbformat                               5.9.2-pyhd8ed1ab_0 --> 5.10.4-pyhd8ed1ab_0
#   ncurses                                    6.4-hcb278e6_0 --> 6.5-h59595ed_0
#   nest-asyncio                           1.5.8-pyhd8ed1ab_0 --> 1.6.0-pyhd8ed1ab_0
#   nodejs                                  20.8.1-h1990674_0 --> 20.12.2-hb753e55_0
#   notebook-shim                          0.2.3-pyhd8ed1ab_0 --> 0.2.4-pyhd8ed1ab_0
#   overrides                              7.4.0-pyhd8ed1ab_0 --> 7.7.0-pyhd8ed1ab_0
#   packaging                               23.2-pyhd8ed1ab_0 --> 24.0-pyhd8ed1ab_0
#   pandoc                                   3.1.3-h32600fe_0 --> 3.2-ha770c72_0
#   parso                                  0.8.3-pyhd8ed1ab_0 --> 0.8.4-pyhd8ed1ab_0
#   pexpect                                4.8.0-pyh1a96a4e_2 --> 4.9.0-pyhd8ed1ab_0
#   platformdirs                          3.11.0-pyhd8ed1ab_0 --> 4.2.2-pyhd8ed1ab_0
#   pluggy                                 1.3.0-pyhd8ed1ab_0 --> 1.5.0-pyhd8ed1ab_0
#   prometheus_client                     0.17.1-pyhd8ed1ab_0 --> 0.20.0-pyhd8ed1ab_0
#   prompt-toolkit                        3.0.39-pyha770c72_0 --> 3.0.42-pyha770c72_0
#   psutil                              5.9.5-py311h459d7ec_1 --> 5.9.8-py311h459d7ec_0
#   pycparser                               2.21-pyhd8ed1ab_0 --> 2.22-pyhd8ed1ab_0
#   pygments                              2.16.1-pyhd8ed1ab_0 --> 2.18.0-pyhd8ed1ab_0
#   pyjwt                                  2.8.0-pyhd8ed1ab_0 --> 2.8.0-pyhd8ed1ab_1
#   pyopenssl                             23.2.0-pyhd8ed1ab_1 --> 24.0.0-pyhd8ed1ab_0
#   python-dateutil                        2.8.2-pyhd8ed1ab_0 --> 2.9.0-pyhd8ed1ab_0
#   python-fastjsonsc~                    2.18.1-pyhd8ed1ab_0 --> 2.19.1-pyhd8ed1ab_0
#   pytz                            2023.3.post1-pyhd8ed1ab_0 --> 2024.1-pyhd8ed1ab_0
#   pyzmq                              25.1.1-py311h75c88c4_1 --> 26.0.3-py311h08a0b41_0
#   referencing                           0.30.2-pyhd8ed1ab_0 --> 0.35.1-pyhd8ed1ab_0
#   reproc                            14.2.4.post0-hd590300_0 --> 14.2.4.post0-hd590300_1
#   reproc-cpp                        14.2.4.post0-h59595ed_0 --> 14.2.4.post0-h59595ed_1
#   requests                              2.31.0-pyhd8ed1ab_0 --> 2.32.3-pyhd8ed1ab_0
#   rpds-py                            0.10.6-py311h46250e7_0 --> 0.18.1-py311h5ecf98a_0
#   ruamel.yaml                       0.17.39-py311h459d7ec_0 --> 0.17.40-py311h459d7ec_0
#   ruamel.yaml.clib                    0.2.7-py311h459d7ec_2 --> 0.2.8-py311h459d7ec_0
#   send2trash                             1.8.2-pyh41d4057_0 --> 1.8.3-pyh0d859eb_0
#   setuptools                            68.2.2-pyhd8ed1ab_0 --> 70.0.0-pyhd8ed1ab_0
#   sniffio                                1.3.0-pyhd8ed1ab_0 --> 1.3.1-pyhd8ed1ab_0
#   sqlalchemy                         2.0.22-py311h459d7ec_0 --> 2.0.30-py311h331c9d8_0
#   terminado                             0.17.1-pyh41d4057_0 --> 0.18.1-pyh0d859eb_0
#   tinycss2                               1.2.1-pyhd8ed1ab_0 --> 1.3.0-pyhd8ed1ab_0
#   tk                                      8.6.13-h2797004_0 --> 8.6.13-noxft_h4845f30_101
#   tornado                             6.3.3-py311h459d7ec_1 --> 6.4-py311h459d7ec_0
#   tqdm                                  4.66.1-pyhd8ed1ab_0 --> 4.66.4-pyhd8ed1ab_0
#   traitlets                             5.11.2-pyhd8ed1ab_0 --> 5.14.3-pyhd8ed1ab_0
#   types-python-date~                 2.8.19.14-pyhd8ed1ab_0 --> 2.9.0.20240316-pyhd8ed1ab_0
#   typing-extensions                        4.8.0-hd8ed1ab_0 --> 4.12.1-hd8ed1ab_0
#   typing_extensions                      4.8.0-pyha770c72_0 --> 4.12.1-pyha770c72_0
#   tzdata                                   2023c-h71feb2d_0 --> 2024a-h0c530f3_0
#   urllib3                                2.0.7-pyhd8ed1ab_0 --> 2.2.1-pyhd8ed1ab_0
#   wcwidth                                0.2.8-pyhd8ed1ab_0 --> 0.2.13-pyhd8ed1ab_0
#   websocket-client                       1.6.4-pyhd8ed1ab_0 --> 1.8.0-pyhd8ed1ab_0
#   zeromq                                   4.3.5-h59595ed_0 --> 4.3.5-h75354e8_4
#   zlib                                    1.2.13-hd590300_5 --> 1.2.13-h4ab18f5_6
#   zstandard                          0.21.0-py311haa97af0_1 --> 0.22.0-py311haa97af0_0
#
# The following packages will be DOWNGRADED:
#
#   ipython_genutils                               0.2.0-py_1 --> 0.2.0-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages:
# libexpat-2.6.2       | 72 KB     |                                       |   0%
# charset-normalizer-3 | 46 KB     |                                       |   0%
#
# psutil-5.9.8         | 494 KB    |                                       |   0%
#
#
# pyzmq-26.0.3         | 464 KB    |                                       |   0%
#
#
#
# pandoc-3.2           | 20.1 MB   |                                       |   0%
#
#
#
#
# alembic-1.13.1       | 155 KB    |                                       |   0%
#
#
#
#
#
# sniffio-1.3.1        | 15 KB     |                                       |   0%
#
#
#
#
#
#
# boltons-24.0.0       | 291 KB    |                                       |   0%
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# importlib_metadata-7 | 9 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
# fmt-10.2.1           | 189 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# c-ares-1.28.1        | 165 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 248 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.6.0   | 11 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-inline-0. | 14 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 218 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonschema-specifica | 16 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# reproc-cpp-14.2.4.po | 25 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.22.0     | 406 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.3     | 116 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   |                                       |   0%
#
# psutil-5.9.8         | 494 KB    | #1                                    |   3%
# libexpat-2.6.2       | 72 KB     | ########2                             |  22%
#
# psutil-5.9.8         | 494 KB    | ###########9                          |  32%
#
#
#
# pandoc-3.2           | 20.1 MB   | 2                                     |   1%
#
#
#
# libexpat-2.6.2       | 72 KB     | ##################################### | 100%
# charset-normalizer-3 | 46 KB     | ##################################### | 100%
# charset-normalizer-3 | 46 KB     | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ##                                    |   6%
#
#
#
#
# alembic-1.13.1       | 155 KB    | ###8                                  |  10%
#
#
#
#
# alembic-1.13.1       | 155 KB    | #######6                              |  21%
#
# psutil-5.9.8         | 494 KB    | ###################1                  |  52%
#
#
#
# pandoc-3.2           | 20.1 MB   | ###8                                  |  10%
#
#
#
#
# alembic-1.13.1       | 155 KB    | ###################                   |  51%
#
# psutil-5.9.8         | 494 KB    | #######################9              |  65%
#
#
#
# pandoc-3.2           | 20.1 MB   | #####3                                |  14%
#
#
#
#
# alembic-1.13.1       | 155 KB    | ##################################### | 100%
#
# psutil-5.9.8         | 494 KB    | ##################################7   |  94%
#
#
#
#
#
#
# boltons-24.0.0       | 291 KB    | ##                                    |   5%
#
#
#
# pandoc-3.2           | 20.1 MB   | #######5                              |  20%
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     | ########################3             |  66%
#
#
# pyzmq-26.0.3         | 464 KB    | #2                                    |   3%
#
#
#
#
#
#
#
#
# importlib_metadata-7 | 9 KB      | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ########5                             |  23%
#
#
#
#
#
#
# boltons-24.0.0       | 291 KB    | ####################3                 |  55%
#
#
# pyzmq-26.0.3         | 464 KB    | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
# fmt-10.2.1           | 189 KB    | ###1                                  |   8%
#
#
#
# pandoc-3.2           | 20.1 MB   | #########6                            |  26%
#
#
# pyzmq-26.0.3         | 464 KB    | ######3                               |  17%
#
#
#
#
#
# sniffio-1.3.1        | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# fmt-10.2.1           | 189 KB    | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
# c-ares-1.28.1        | 165 KB    | ###5                                  |  10%
#
#
#
# pandoc-3.2           | 20.1 MB   | ##########8                           |  29%
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# pyjwt-2.8.0          | 24 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 19 KB     | ##############################5       |  83%
#
#
#
# pandoc-3.2           | 20.1 MB   | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     | ##################3                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.6.0   | 11 KB     | ##################################### | 100%
#
#
# pyzmq-26.0.3         | 464 KB    | ##########2                           |  28%
#
#
#
#
#
#
#
#
# importlib_metadata-7 | 9 KB      | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ############7                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 248 KB    | ##3                                   |   6%
#
#
# pyzmq-26.0.3         | 464 KB    | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 248 KB    | #####################4                |  58%
#
#
#
# pandoc-3.2           | 20.1 MB   | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 218 KB    | ##7                                   |   7%
#
#
#
#
# alembic-1.13.1       | 155 KB    | ##################################### | 100%
#
# psutil-5.9.8         | 494 KB    | ##################################### | 100%
#
#
# pyzmq-26.0.3         | 464 KB    | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 248 KB    | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 218 KB    | ###########################2          |  74%
#
#
#
# pandoc-3.2           | 20.1 MB   | ##############8                       |  40%
#
#
# pyzmq-26.0.3         | 464 KB    | ####################4                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonschema-specifica | 16 KB     | ####################################8 | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ###############8                      |  43%
#
#
# pyzmq-26.0.3         | 464 KB    | #########################5            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-inline-0. | 14 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# reproc-cpp-14.2.4.po | 25 KB     | #######################8              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    | #####                                 |  14%
#
#
#
#
#
# sniffio-1.3.1        | 15 KB     | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ################8                     |  45%
#
#
#
# pandoc-3.2           | 20.1 MB   | #################9                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.3     | 116 KB    | #####                                 |  14%
#
#
# pyzmq-26.0.3         | 464 KB    | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
# fmt-10.2.1           | 189 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# fmt-10.2.1           | 189 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.22.0     | 406 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.22.0     | 406 KB    | #############1                        |  35%
#
#
#
# pandoc-3.2           | 20.1 MB   | ####################1                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.22.0     | 406 KB    | ####################4                 |  55%
#
#
#
# pandoc-3.2           | 20.1 MB   | #####################3                |  58%
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.22.0     | 406 KB    | ##############################6       |  83%
#
#
#
# pandoc-3.2           | 20.1 MB   | ######################3               |  60%
#
#
#
#
#
#
# boltons-24.0.0       | 291 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# boltons-24.0.0       | 291 KB    | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.6.0   | 11 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ########################4             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | #########################5            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 248 KB    | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ###########################5          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# c-ares-1.28.1        | 165 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# c-ares-1.28.1        | 165 KB    | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 218 KB    | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-inline-0. | 14 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonschema-specifica | 16 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# reproc-cpp-14.2.4.po | 25 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# reproc-cpp-14.2.4.po | 25 KB     | ##################################### | 100%
#
#
#
# pandoc-3.2           | 20.1 MB   | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.3     | 116 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.3     | 116 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstandard-0.22.0     | 406 KB    | ##################################### | 100%
#
#
# pyzmq-26.0.3         | 464 KB    | ##################################### | 100%
#
#
# pyzmq-26.0.3         | 464 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 117 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# pandoc-3.2           | 20.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### mySQL Client

# %%
conda install mysqlclient
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - mysqlclient
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mysqlclient-2.2.4          |  py311hb755f60_1          98 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          98 KB
#
# The following NEW packages will be INSTALLED:
#
#   mysqlclient        conda-forge/linux-64::mysqlclient-2.2.4-py311hb755f60_1
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c conda-forge conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connect to DB

# %%
# %load_ext sql
# Out:
# There's a new jupysql version available (0.10.10), you're running 0.10.9. To upgrade: pip install jupysql --upgrade
# Deploy Streamlit apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup

# %%
# %sql mysql://jovyan:password@180.233.121.154:18033/hanisntsolo
# Out:
# Connecting to 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql use information_schema;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %config SqlMagic.displaylimit = None
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %sql select * from table_privileges;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |           GRANTEE           | TABLE_CATALOG | TABLE_SCHEMA | TABLE_NAME | PRIVILEGE_TYPE | IS_GRANTABLE |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |   'mysql.sys'@'localhost'   |      def      |     sys      | sys_config |     SELECT     |      NO      |
# | 'mysql.session'@'localhost' |      def      |    mysql     |    user    |     SELECT     |      NO      |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+

# %%
# %sql use hanisntsolo
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# +-----------------------+
# | Tables_in_hanisntsolo |
# +-----------------------+
# +-----------------------+

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql use sweta;
# %sql show tables;
# %sql select * from employee;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++
