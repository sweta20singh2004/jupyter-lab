# %% [markdown]
# # DATABASE CONNECTIVITY

# %%
conda install mysql-connector-python
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Start

# %%
import mysql.connector
import pandas as pd 
import os

# %%
import mysql.connector
import os

# Retrieve MySQL connection credentials from environment variables
mysql_user = 'jovyan'
mysql_password = 'password'
mysql_database = 'hanisntsolo'
# MySQL database connection configuration
mysql_config = {
    'host': '180.233.121.154',
    'port': 18033,
    'user': mysql_user,
    'password': mysql_password,
    'database': mysql_database
}

try:
    # Connect to MySQL database
    conn = mysql.connector.connect(**mysql_config)
    print("Connected to MySQL database")

    # Perform database operations here

except mysql.connector.Error as err:
    print("Error connecting to MySQL:", err)

finally:
    # Close the database connection
    if 'conn' in locals() and conn.is_connected():
        conn.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL database
# MySQL connection closed

# %% [markdown]
# ## Install JupySQL & MySQL Client

# %% [markdown]
# ### JUPYSQL

# %%
conda install jupysql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backoff-2.2.1              |     pyhd8ed1ab_0          17 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     jupysql-0.10.9             |     pyhd8ed1ab_0          78 KB  conda-forge
#     jupysql-plugin-0.4.3       |     pyhd8ed1ab_0         215 KB  conda-forge
#     monotonic-1.5              |     pyhd8ed1ab_1          13 KB  conda-forge
#     ploomber-core-0.2.25       |     pyhd8ed1ab_0          29 KB  conda-forge
#     posthog-3.5.0              |     pyhd8ed1ab_1          39 KB  conda-forge
#     prettytable-3.10.0         |     pyhd8ed1ab_0          29 KB  conda-forge
#     sqlglot-24.1.0             |     pyhd8ed1ab_0         264 KB  conda-forge
#     sqlparse-0.5.0             |     pyhd8ed1ab_0          39 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         807 KB
#
# The following NEW packages will be INSTALLED:
#
#   backoff            conda-forge/noarch::backoff-2.2.1-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   jupysql            conda-forge/noarch::jupysql-0.10.9-pyhd8ed1ab_0
#   jupysql-plugin     conda-forge/noarch::jupysql-plugin-0.4.3-pyhd8ed1ab_0
#   monotonic          conda-forge/noarch::monotonic-1.5-pyhd8ed1ab_1
#   ploomber-core      conda-forge/noarch::ploomber-core-0.2.25-pyhd8ed1ab_0
#   posthog            conda-forge/noarch::posthog-3.5.0-pyhd8ed1ab_1
#   prettytable        conda-forge/noarch::prettytable-3.10.0-pyhd8ed1ab_0
#   sqlglot            conda-forge/noarch::sqlglot-24.1.0-pyhd8ed1ab_0
#   sqlparse           conda-forge/noarch::sqlparse-0.5.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# sqlglot-24.1.0       | 264 KB    |                                       |   0%
# monotonic-1.5        | 13 KB     |                                       |   0%
#
# posthog-3.5.0        | 39 KB     |                                       |   0%
#
#
# backoff-2.2.1        | 17 KB     |                                       |   0%
#
#
#
# ploomber-core-0.2.25 | 29 KB     |                                       |   0%
#
#
#
#
# prettytable-3.10.0   | 29 KB     |                                       |   0%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     |                                       |   0%
#
#
#
#
#
#
# jupysql-0.10.9       | 78 KB     |                                       |   0%
#
#
#
#
#
#
#
# jupysql-plugin-0.4.3 | 215 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# click-8.1.7          | 82 KB     |                                       |   0%
#
#
# backoff-2.2.1        | 17 KB     | ##################################6   |  94%
#
#
# backoff-2.2.1        | 17 KB     | ##################################### | 100%
# monotonic-1.5        | 13 KB     | ##################################### | 100%
# monotonic-1.5        | 13 KB     | ##################################### | 100%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     | ###############                       |  41%
#
# posthog-3.5.0        | 39 KB     | ###############3                      |  41%
#
#
#
#
# sqlglot-24.1.0       | 264 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
# click-8.1.7          | 82 KB     | #######1                              |  19%
#
#
#
#
# prettytable-3.10.0   | 29 KB     | ##################################### | 100%
#
#
#
#
# prettytable-3.10.0   | 29 KB     | ##################################### | 100%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     | ##################################### | 100%
#
# posthog-3.5.0        | 39 KB     | ##################################### | 100%
#
#
#
#
#
# sqlparse-0.5.0       | 39 KB     | ##################################### | 100%
#
# posthog-3.5.0        | 39 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# click-8.1.7          | 82 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# sqlglot-24.1.0       | 264 KB    | ######################3               |  60%
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ####################5                 |  55%
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ##################################### | 100%
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# sqlglot-24.1.0       | 264 KB    | ##################################### | 100%
#
#
#
#
#
#
# jupysql-0.10.9       | 78 KB     | #######5                              |  20%
#
#
#
#
#
#
#
# jupysql-plugin-0.4.3 | 215 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# jupysql-plugin-0.4.3 | 215 KB    | ##################################### | 100%
#
#
#
#
#
#
# jupysql-0.10.9       | 78 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda upgrade jupysql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /

# %% [markdown]
# ### mySQL Client

# %%
conda install mysqlclient

# %%
conda update -n base -c conda-forge conda

# %% [markdown]
# ## Connect to DB

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/extensions.py:76, in ExtensionManager.load_extension(self, module_str)
#      69 """Load an IPython extension by its module name.
#      70
#      71 Returns the string "already loaded" if the extension is already loaded,
#      72 "no load function" if the module doesn't have a load_ipython_extension
#      73 function, or None if it succeeded.
#      74 """
#      75 try:
# ---> 76     return self._load_extension(module_str)
#      77 except ModuleNotFoundError:
#      78     if module_str in BUILTINS_EXTS:
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/extensions.py:91, in ExtensionManager._load_extension(self, module_str)
#      89 with self.shell.builtin_trap:
#      90     if module_str not in sys.modules:
# ---> 91         mod = import_module(module_str)
#      92     mod = sys.modules[module_str]
#      93     if self._call_load_ipython_extension(mod):
#
# File /opt/conda/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sql'

# %%
# %sql mysql://jovyan:password@180.233.121.154:18033/hanisntsolo
# Out:
# Connecting and switching to connection 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql use information_schema;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %config SqlMagic.displaylimit = None
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %sql select * from table_privileges;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |           GRANTEE           | TABLE_CATALOG | TABLE_SCHEMA | TABLE_NAME | PRIVILEGE_TYPE | IS_GRANTABLE |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |   'mysql.sys'@'localhost'   |      def      |     sys      | sys_config |     SELECT     |      NO      |
# | 'mysql.session'@'localhost' |      def      |    mysql     |    user    |     SELECT     |      NO      |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+

# %%
# %sql use hanisntsolo
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# +-----------------------+
# | Tables_in_hanisntsolo |
# +-----------------------+
# +-----------------------+

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql use sweta;
# %sql show tables;
# %sql select * from employee;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++
