# %% [markdown]
# # DATABASE CONNECTIVITY

# %%
conda install mysql-connector-python
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done

# %% [markdown]
# # Start

# %%
import mysql.connector
import pandas as pd 
import os

# %%
import mysql.connector
import os

# Retrieve MySQL connection credentials from environment variables
mysql_user = 'jovyan'
mysql_password = 'password'
mysql_database = 'hanisntsolo'
# MySQL database connection configuration
mysql_config = {
    'host': '180.233.121.154',
    'port': 18033,
    'user': mysql_user,
    'password': mysql_password,
    'database': mysql_database
}

try:
    # Connect to MySQL database
    conn = mysql.connector.connect(**mysql_config)
    print("Connected to MySQL database")

    # Perform database operations here

except mysql.connector.Error as err:
    print("Error connecting to MySQL:", err)

finally:
    # Close the database connection
    if 'conn' in locals() and conn.is_connected():
        conn.close()
        print("MySQL connection closed")

# %% [markdown]
# ## Install JupySQL & MySQL Client

# %% [markdown]
# ### JUPYSQL

# %%
conda install jupysql
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.3.0
#     latest version: 24.4.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backoff-2.2.1              |     pyhd8ed1ab_0          17 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     jupysql-0.10.9             |     pyhd8ed1ab_0          78 KB  conda-forge
#     jupysql-plugin-0.4.3       |     pyhd8ed1ab_0         215 KB  conda-forge
#     monotonic-1.5              |             py_0           9 KB  conda-forge
#     ploomber-core-0.2.25       |     pyhd8ed1ab_0          29 KB  conda-forge
#     posthog-3.5.0              |     pyhd8ed1ab_1          39 KB  conda-forge
#     prettytable-3.10.0         |     pyhd8ed1ab_0          29 KB  conda-forge
#     sqlglot-23.15.1            |     pyhd8ed1ab_0         276 KB  conda-forge
#     sqlparse-0.5.0             |     pyhd8ed1ab_0          39 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         814 KB
#
# The following NEW packages will be INSTALLED:
#
#   backoff            conda-forge/noarch::backoff-2.2.1-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   jupysql            conda-forge/noarch::jupysql-0.10.9-pyhd8ed1ab_0
#   jupysql-plugin     conda-forge/noarch::jupysql-plugin-0.4.3-pyhd8ed1ab_0
#   monotonic          conda-forge/noarch::monotonic-1.5-py_0
#   ploomber-core      conda-forge/noarch::ploomber-core-0.2.25-pyhd8ed1ab_0
#   posthog            conda-forge/noarch::posthog-3.5.0-pyhd8ed1ab_1
#   prettytable        conda-forge/noarch::prettytable-3.10.0-pyhd8ed1ab_0
#   sqlglot            conda-forge/noarch::sqlglot-23.15.1-pyhd8ed1ab_0
#   sqlparse           conda-forge/noarch::sqlparse-0.5.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# sqlglot-23.15.1      | 276 KB    |                                       |   0%
# jupysql-plugin-0.4.3 | 215 KB    |                                       |   0%
#
# click-8.1.7          | 82 KB     |                                       |   0%
#
#
# jupysql-0.10.9       | 78 KB     |                                       |   0%
#
#
#
# sqlparse-0.5.0       | 39 KB     |                                       |   0%
#
#
#
#
# posthog-3.5.0        | 39 KB     |                                       |   0%
#
#
#
#
#
# prettytable-3.10.0   | 29 KB     |                                       |   0%
#
#
#
#
#
#
# ploomber-core-0.2.25 | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
# backoff-2.2.1        | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# monotonic-1.5        | 9 KB      |                                       |   0%
#
#
#
# sqlparse-0.5.0       | 39 KB     | ###############                       |  41%
#
# click-8.1.7          | 82 KB     | #######1                              |  19%
#
#
#
# sqlparse-0.5.0       | 39 KB     | ##################################### | 100%
#
# sqlglot-23.15.1      | 276 KB    | ##1                                   |   6%
#
#
#
#
#
# prettytable-3.10.0   | 29 KB     | ####################1                 |  54%
#
#
#
#
#
# prettytable-3.10.0   | 29 KB     | ##################################### | 100%
#
#
#
#
# sqlglot-23.15.1      | 276 KB    | ##################################### | 100%
#
#
#
#
# posthog-3.5.0        | 39 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# monotonic-1.5        | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
# monotonic-1.5        | 9 KB      | ##################################### | 100%
# jupysql-plugin-0.4.3 | 215 KB    | ##7                                   |   7%
#
#
#
#
#
#
#
# backoff-2.2.1        | 17 KB     | ##################################6   |  94%
#
#
#
#
#
#
#
# backoff-2.2.1        | 17 KB     | ##################################### | 100%
# jupysql-plugin-0.4.3 | 215 KB    | ###################################7  |  97%
# jupysql-plugin-0.4.3 | 215 KB    | ##################################### | 100%
#
#
#
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ####################5                 |  55%
#
#
#
#
#
#
# ploomber-core-0.2.25 | 29 KB     | ##################################### | 100%
#
#
# jupysql-0.10.9       | 78 KB     | #######5                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda upgrade jupysql
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.3.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### mySQL Client

# %%
conda install mysqlclient
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.3.0
#     latest version: 24.4.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - mysqlclient
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mysqlclient-2.2.4          |  py311hb755f60_1          98 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          98 KB
#
# The following NEW packages will be INSTALLED:
#
#   mysqlclient        conda-forge/linux-64::mysqlclient-2.2.4-py311hb755f60_1
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c conda-forge conda
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-24.5.0               |  py311h38be061_0         1.2 MB  conda-forge
#     frozendict-2.4.4           |  py311h331c9d8_0          31 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   frozendict         conda-forge/linux-64::frozendict-2.4.4-py311h331c9d8_0
#
# The following packages will be UPDATED:
#
#   conda                              24.3.0-py311h38be061_0 --> 24.5.0-py311h38be061_0
#
#
#
# Downloading and Extracting Packages:
# conda-24.5.0         | 1.2 MB    |                                       |   0%
# conda-24.5.0         | 1.2 MB    | 4                                     |   1%
# frozendict-2.4.4     | 31 KB     | ###################4                  |  52%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connect to DB

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql://jovyan:password@180.233.121.154:18033/hanisntsolo
# Out:
# Connecting and switching to connection 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql use information_schema;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %config SqlMagic.displaylimit = None
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %sql select * from table_privileges;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |           GRANTEE           | TABLE_CATALOG | TABLE_SCHEMA | TABLE_NAME | PRIVILEGE_TYPE | IS_GRANTABLE |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |   'mysql.sys'@'localhost'   |      def      |     sys      | sys_config |     SELECT     |      NO      |
# | 'mysql.session'@'localhost' |      def      |    mysql     |    user    |     SELECT     |      NO      |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+

# %%
# %sql use hanisntsolo
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# +-----------------------+
# | Tables_in_hanisntsolo |
# +-----------------------+
# +-----------------------+

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 11 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# +--------------------+
# Truncated to displaylimit of 10.

# %%
# %sql use sweta;
# %sql show tables;
# %sql select * from employee;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++
