# %% [markdown]
# # TERMINAL

# %%
# sudo apt update
# sudo apt install mysql-client

# %% [markdown]
# mysql -u jovyan -p -h 180.233.121.154 -P 18033 -D hanisntsolo;

# %% [markdown]
# mysql -u jovyan -ppassword -h 180.233.121.154 -P 18033 -D sweta

# %% [markdown]
# # DATABASE CONNECTIVITY

# %%
conda install mysql-connector-python
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.11.3
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.11.3
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Start

# %%
import mysql.connector
import pandas as pd 
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mysql.connector
#       2 import pandas as pd
#       3 import os
#
# ModuleNotFoundError: No module named 'mysql'

# %%
import mysql.connector
import os

# Retrieve MySQL connection credentials from environment variables
mysql_user = 'jovyan'
mysql_password = 'password'
mysql_database = 'hanisntsolo'
# MySQL database connection configuration
mysql_config = {
    'host': '180.233.121.154',
    'port': 18033,
    'user': mysql_user,
    'password': mysql_password,
    'database': mysql_database
}

try:
    # Connect to MySQL database
    conn = mysql.connector.connect(**mysql_config)
    print("Connected to MySQL database")

    # Perform database operations here

except mysql.connector.Error as err:
    print("Error connecting to MySQL:", err)

finally:
    # Close the database connection
    if 'conn' in locals() and conn.is_connected():
        conn.close()
        print("MySQL connection closed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import mysql.connector
#       2 import os
#       4 # Retrieve MySQL connection credentials from environment variables
#
# ModuleNotFoundError: No module named 'mysql'

# %% [markdown]
# ## Install JupySQL & MySQL Client

# %% [markdown]
# ### JUPYSQL

# %%
conda install jupysql
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.9.1
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backoff-2.2.1              |     pyhd8ed1ab_0          17 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     jupysql-0.10.14            |     pyhd8ed1ab_0          78 KB  conda-forge
#     jupysql-plugin-0.4.5       |     pyhd8ed1ab_0         167 KB  conda-forge
# ...

# %%
conda upgrade jupysql
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alembic-1.13.2             |     pyhd8ed1ab_0         155 KB  conda-forge
#     anyio-4.4.0                |     pyhd8ed1ab_0         102 KB  conda-forge
#     bzip2-1.0.8                |       h4bc722e_7         247 KB  conda-forge
#     c-ares-1.32.3              |       h4bc722e_0         176 KB  conda-forge
# ...

# %% [markdown]
# ### mySQL Client

# %%
conda install mysqlclient
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.9.1
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - mysqlclient
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mysqlclient-2.2.4          |  py311hb755f60_1          98 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          98 KB
#
# The following NEW packages will be INSTALLED:
#
#   mysqlclient        conda-forge/linux-64::mysqlclient-2.2.4-py311hb755f60_1
#
#
#
# ...
#
# Preparing transaction: done
# ...

# %%
conda update -n base -c conda-forge conda
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connect to DB

# %%
# %load_ext sql
# Out:
# displaylimit: Value None will be treated as 0 (no limit)

# %%
# %sql mysql://jovyan:password@180.233.121.154:18033/hanisntsolo
# Out:
# Connecting to 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 5 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |        sys         |
# +--------------------+

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 5 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |        sys         |
# +--------------------+

# %%
# %sql use information_schema;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %config SqlMagic.displaylimit = None

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# |             ENABLED_ROLES             |
# |                ENGINES                |
# |                 EVENTS                |
# |                 FILES                 |
# |           INNODB_BUFFER_PAGE          |
# |         INNODB_BUFFER_PAGE_LRU        |
# |        INNODB_BUFFER_POOL_STATS       |
# ...

# %%
# %sql select * from table_privileges;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |           GRANTEE           | TABLE_CATALOG | TABLE_SCHEMA | TABLE_NAME | PRIVILEGE_TYPE | IS_GRANTABLE |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+
# |   'mysql.sys'@'localhost'   |      def      |     sys      | sys_config |     SELECT     |      NO      |
# | 'mysql.session'@'localhost' |      def      |    mysql     |    user    |     SELECT     |      NO      |
# +-----------------------------+---------------+--------------+------------+----------------+--------------+

# %%
# %sql use hanisntsolo
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# |             ENABLED_ROLES             |
# |                ENGINES                |
# |                 EVENTS                |
# |                 FILES                 |
# |           INNODB_BUFFER_PAGE          |
# |         INNODB_BUFFER_PAGE_LRU        |
# |        INNODB_BUFFER_POOL_STATS       |
# ...

# %%
# %sql show databases;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 12 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |       SINGH        |
# |         db         |
# |    hanisntsolo     |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |       sakila       |
# |       sports       |
# |  student_project   |
# |       sweta        |
# |        sys         |
# |       world        |
# +--------------------+

# %%
# %sql use sweta;
# %sql show tables;
# %sql select * from employee;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 79 rows affected.
# +---------------------------------------+
# |      Tables_in_information_schema     |
# +---------------------------------------+
# |   ADMINISTRABLE_ROLE_AUTHORIZATIONS   |
# |            APPLICABLE_ROLES           |
# |             CHARACTER_SETS            |
# |           CHECK_CONSTRAINTS           |
# |               COLLATIONS              |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# |                COLUMNS                |
# |           COLUMNS_EXTENSIONS          |
# |           COLUMN_PRIVILEGES           |
# |           COLUMN_STATISTICS           |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# +-----------------------+
# | Tables_in_hanisntsolo |
# +-----------------------+
# +-----------------------+

# %%
# %sql select * from STUDENT;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (MySQLdb.ProgrammingError) (1146, "Table 'hanisntsolo.STUDENT' doesn't exist")
# [SQL: select * from STUDENT;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %sql select max(Marks) from STUDENT group by Gender;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +------------+
# | max(Marks) |
# +------------+
# |    440     |
# |    492     |
# +------------+

# %%
# %sql select min(Marks) from STUDENT group by City;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# RuntimeError: (MySQLdb.OperationalError) (1109, "Unknown table 'STUDENT' in information_schema")
# [SQL: select min(Marks) from STUDENT group by City;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %sql select Gender, count(Gender) from STUDENT group by Gender;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +--------+---------------+
# | Gender | count(Gender) |
# +--------+---------------+
# |   M    |       4       |
# |   F    |       4       |
# +--------+---------------+

# %%
# %sql select * from vehicles;

# %%
# %sql select Type , avg(Price) from vehicles group by Type having qty>20;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# RuntimeError: (MySQLdb.OperationalError) (1054, "Unknown column 'qty' in 'having clause'")
# [SQL: select Type , avg(Price) from vehicles group by Type having qty>20;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %sql select Company , count(distinct Type) from vehicles group by Company;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 4 rows affected.
# +------------+----------------------+
# |  Company   | count(distinct Type) |
# +------------+----------------------+
# |   Datsun   |          1           |
# |  Mahindra  |          2           |
# |   Maruti   |          2           |
# | Mitsubishi |          1           |
# +------------+----------------------+

# %%
# %sql select Type , sum(Price*Qty) from vehicles group by Type ;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 4 rows affected.
# +----------+----------------+
# |   Type   | sum(Price*Qty) |
# +----------+----------------+
# |  Wagon   |   6250000.0    |
# |   Jeep   |   60000000.0   |
# |   SUV    |   90000000.0   |
# | Mini van |   44250000.0   |
# +----------+----------------+

# %%
# %sql USE sweta;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql use sweta;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# ++
# ||
# ++
# ++

# %%
# %sql show tables;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 37 rows affected.
# +-----------------+
# | Tables_in_sweta |
# +-----------------+
# |     ACTIVITY    |
# |      CABHUB     |
# |      COACH      |
# |     CUSTOMER    |
# |     EMPLOYEE    |
# |      GAMES      |
# |     PAYLEVEL    |
# |      PLAYER     |
# |     POSTING     |
# |    SALEGRADE    |
# |      STORE      |
# |     STUDENT     |
# |    SUPPLIERS    |
# |     TEACHER     |
# |      WORKER     |
# |       cand      |
# |       club      |
# |     employee    |
# |      event      |
# |      items      |
# |       job       |
# |      kajal      |
# |       mov       |
# |      movie      |
# |       old       |
# |      oldstu     |
# |       pet       |
# |     register    |
# |      singh      |
# |      singhs     |
# |      sports     |
# |     student     |
# |     student1    |
# |   student_ace   |
# |     subject     |
# |  sweta_friends  |
# |     vehicles    |
# +-----------------+

# %%
# %sql select * from TEACHER;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 8 rows affected.
# +------+----------+-----+-------------+------------+--------+--------+
# | T_ID |   Name   | Age |  Department | Join_Date  | Salary | Gender |
# +------+----------+-----+-------------+------------+--------+--------+
# |  1   |  Jugal   |  34 | Computer Sc | 2017-01-10 | 12000  |   M    |
# |  2   | Sharmila |  31 |   History   | 2008-03-24 | 20000  |   F    |
# |  3   | Sandeep  |  32 | Mathematics | 2016-12-12 | 30000  |   M    |
# |  4   | Sangeeta |  35 |   History   | 2015-07-01 | 40000  |   F    |
# |  5   |  Rakesh  |  42 | Mathematics | 2007-09-05 | 25000  |   M    |
# |  6   |  Shyam   |  50 |   History   | 2008-06-26 | 30000  |   M    |
# |  7   | Shiv Om  |  44 | Computer Sc | 2017-02-25 | 21000  |   M    |
# |  8   | Shalakha |  33 | Mathematics | 2018-07-31 | 20000  |   F    |
# +------+----------+-----+-------------+------------+--------+--------+

# %%
# %sql select Department, Count(*), from TEACHER Group by Department;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (MySQLdb.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'from TEACHER Group by Department' at line 1")
# [SQL: select Department, Count(*), from TEACHER Group by Department;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %sql select * from GAMES;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 5 rows affected.
# +-------+--------------+---------+--------+------------+--------------+
# | GCode |   GameName   |   Type  | Number | PrizeMoney | ScheduleDate |
# +-------+--------------+---------+--------+------------+--------------+
# |  101  | Carom Board  |  Indoor |   2    |    5000    |  2004-01-23  |
# |  102  |  Badminton   | Outdoor |   2    |   12000    |  2003-12-12  |
# |  103  | Teble Tennis |  Indoor |   4    |    8000    |  2004-02-14  |
# |  105  |    Chess     |  Indoor |   2    |    9000    |  2004-01-01  |
# |  108  | Lawn Tennis  | Outdoor |   4    |   25000    |  2004-03-19  |
# +-------+--------------+---------+--------+------------+--------------+

# %%
# %sql SELECT GameName, GCode from GAMES where PrizeMoney>7000;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 4 rows affected.
# +--------------+-------+
# |   GameName   | GCode |
# +--------------+-------+
# |  Badminton   |  102  |
# | Teble Tennis |  103  |
# |    Chess     |  105  |
# | Lawn Tennis  |  108  |
# +--------------+-------+

# %%
# %sql select * from GAMES order by ScheduleDate;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 5 rows affected.
# +-------+--------------+---------+--------+------------+--------------+
# | GCode |   GameName   |   Type  | Number | PrizeMoney | ScheduleDate |
# +-------+--------------+---------+--------+------------+--------------+
# |  102  |  Badminton   | Outdoor |   2    |   12000    |  2003-12-12  |
# |  105  |    Chess     |  Indoor |   2    |    9000    |  2004-01-01  |
# |  101  | Carom Board  |  Indoor |   2    |    5000    |  2004-01-23  |
# |  103  | Teble Tennis |  Indoor |   4    |    8000    |  2004-02-14  |
# |  108  | Lawn Tennis  | Outdoor |   4    |   25000    |  2004-03-19  |
# +-------+--------------+---------+--------+------------+--------------+

# %%
# %sql select sum(PrizeMoney), Type from GAMES group by Type;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +-----------------+---------+
# | sum(PrizeMoney) |   Type  |
# +-----------------+---------+
# |      22000      |  Indoor |
# |      37000      | Outdoor |
# +-----------------+---------+

# %%
# %sql select * from CABHUB;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 5 rows affected.
# +-------+-------------+----------+--------+----------+---------+
# | Vcode | VehicleName |   Make   | Color  | Capacity | Charges |
# +-------+-------------+----------+--------+----------+---------+
# |  100  |    Innova   |  Toyota  | White  |    7     |    15   |
# |  102  |     SX4     |  Suzuki  |  Blue  |    4     |    14   |
# |  104  |   C Class   | Mercedes |  Red   |    4     |    35   |
# |  105  |    A-Star   |  Suzuki  | White  |    3     |    14   |
# |  108  |    Indigo   |   Tata   | Silver |    3     |    12   |
# +-------+-------------+----------+--------+----------+---------+

# %%
# %sql select * from CUSTOMER;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 4 rows affected.
# +-------+-------------+-------+
# | CCode |    CName    | Vcode |
# +-------+-------------+-------+
# |   1   | Hemant Sahu |  101  |
# |   2   |  Raj Singh  |  108  |
# |   3   |  Dev Singh  |  105  |
# |   4   | Rudra Singh |  104  |
# +-------+-------------+-------+

# %%
# %sql select VehicleName from CABHUB where Color = 'White';
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 2 rows affected.
# +-------------+
# | VehicleName |
# +-------------+
# |    Innova   |
# |    A-Star   |
# +-------------+

# %%
# %sql select VehicleName, Make, Capacity from CABHUB order by Capacity;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 5 rows affected.
# +-------------+----------+----------+
# | VehicleName |   Make   | Capacity |
# +-------------+----------+----------+
# |    A-Star   |  Suzuki  |    3     |
# |    Indigo   |   Tata   |    3     |
# |     SX4     |  Suzuki  |    4     |
# |   C Class   | Mercedes |    4     |
# |    Innova   |  Toyota  |    7     |
# +-------------+----------+----------+

# %%
# %sql select max(charges) from CABHUB;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 1 rows affected.
# +--------------+
# | max(charges) |
# +--------------+
# |      35      |
# +--------------+

# %%
# %sql select CName, VehicleName from CUSTOMER, CABHUB where CUSTOMER.Vcode = CABHUB.Vcode;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 3 rows affected.
# +-------------+-------------+
# |    CName    | VehicleName |
# +-------------+-------------+
# | Rudra Singh |   C Class   |
# |  Dev Singh  |    A-Star   |
# |  Raj Singh  |    Indigo   |
# +-------------+-------------+

# %%
# %sql select * from ACTIVITY;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 5 rows affected.
# +-------+---------------+-------------+-----------------+------------+--------------+
# | Acode |  ActivityName |   Stadium   | ParticipantsNum | PrizeMoney | ScheduleDate |
# +-------+---------------+-------------+-----------------+------------+--------------+
# |  1001 | Relay 100 x 4 |  Star Annex |        16       |   10000    |  2023-01-04  |
# |  1002 |   High Jump   |  Star Annex |        10       |   12000    |  2012-12-03  |
# |  1003 |    Shot Put   | Super Power |        12       |    8000    |  2014-02-04  |
# |  1005 |   Long Jump   |  Star Annex |        12       |    9000    |  2001-01-04  |
# |  1008 | Discuss Throw | Super Power |        10       |   15000    |  2019-03-04  |
# +-------+---------------+-------------+-----------------+------------+--------------+

# %%
# %sql SELECT * FROM COACH;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 4 rows affected.
# +-------+---------------+-------+
# | Pcode |      Name     | Acode |
# +-------+---------------+-------+
# |   1   | Ahmad Hussain |  1001 |
# |   2   |    Ravindra   |  1008 |
# |   3   |     Janila    |  1001 |
# |   4   |      Naaz     |  1003 |
# +-------+---------------+-------+

# %%
# %sql select COUNT(DISTINCT ParticipantsNum) from ACTIVITY;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 1 rows affected.
# +---------------------------------+
# | COUNT(DISTINCT ParticipantsNum) |
# +---------------------------------+
# |                3                |
# +---------------------------------+

# %%
# %sql select Max(ScheduleDate), Min(ScheduleDate) from ACTIVITY;
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %sql SELECT Name, ActivityName from ACTIVITY A  ,COACH C Where A.Acode = C.Acode and A.ParticipantsNum = 10;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 1 rows affected.
# +----------+---------------+
# |   Name   |  ActivityName |
# +----------+---------------+
# | Ravindra | Discuss Throw |
# +----------+---------------+

# %%
# %sql select * from Product;
# Out:
# Running query in 'mysql://jovyan:***@180.233.121.154:18033/hanisntsolo'
# 6 rows affected.
# +-------+---------------+---------+-------------+----------+
# | Pcode |     PName     |  UPrice | Manufacture | Discount |
# +-------+---------------+---------+-------------+----------+
# |  P01  | WashingPowder |  120.0  |     Surf    |   12.0   |
# |  P02  |   ToothPaste  |   54.0  |   Colgate   |   None   |
# |  P03  |      Soap     |   25.0  |     Lux     |   None   |
# |  P04  |   ToothPaste  |   65.0  |  Pepsodant  |   None   |
# |  P05  |      Soap     | 53.3873 |     Dove    |   None   |
# |  P06  |    Shampoo    | 344.207 |     Dove    | 30.7328  |
# +-------+---------------+---------+-------------+----------+

# %%
# %sql select PName, Average(UPrice) from Product group
