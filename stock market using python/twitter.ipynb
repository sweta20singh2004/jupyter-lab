# %%
pip install tweepy pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 kB 1.5 MB/s eta 0:00:00ta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import pandas as pd

# Twitter API credentials
api_key = 'GKn1Bzsp7LFysmXtN4ij3tldM'
api_secret_key = 'cKiOIcJGaRKFCoZbPTS3gHPs0PpDGzXCCuGoaqi6s6qRWH6T88'
access_token = '1263138856578105344-ed17kVOXeJrrfJAZfttSSfwivUeqbf'
access_token_secret = 'yXb3dELXjeqpzOzY8qjA3Lcee0MeN03LhbxheRquYpTpl'

# Authenticate to the API
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# Define the keyword and number of tweets to search
keyword = 'Python'
num_tweets = 10

# Search for tweets containing the keyword
tweets = tweepy.Cursor(api.search_tweets, q=keyword, lang="en").items(num_tweets)

# Create a list to store tweet details
tweets_list = [[tweet.created_at, tweet.user.screen_name, tweet.text] for tweet in tweets]

# Create a DataFrame from the list
df = pd.DataFrame(tweets_list, columns=['Datetime', 'Username', 'Tweet'])

# Print the DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv('tweets.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[2], line 23
#      20 tweets = tweepy.Cursor(api.search_tweets, q=keyword, lang="en").items(num_tweets)
#      22 # Create a list to store tweet details
# ---> 23 tweets_list = [[tweet.created_at, tweet.user.screen_name, tweet.text] for tweet in tweets]
#      25 # Create a DataFrame from the list
#      26 df = pd.DataFrame(tweets_list, columns=['Datetime', 'Username', 'Tweet'])
#
# Cell In[2], line 23, in <listcomp>(.0)
#      20 tweets = tweepy.Cursor(api.search_tweets, q=keyword, lang="en").items(num_tweets)
#      22 # Create a list to store tweet details
# ---> 23 tweets_list = [[tweet.created_at, tweet.user.screen_name, tweet.text] for tweet in tweets]
#      25 # Create a DataFrame from the list
#      26 df = pd.DataFrame(tweets_list, columns=['Datetime', 'Username', 'Tweet'])
#
# ...

# %%
import tweepy
import pandas as pd

# Twitter API credentials
api_key = 'GKn1Bzsp7LFysmXtN4ij3tldM'
api_secret_key = 'cKiOIcJGaRKFCoZbPTS3gHPs0PpDGzXCCuGoaqi6s6qRWH6T88'
access_token = '1263138856578105344-ed17kVOXeJrrfJAZfttSSfwivUeqbf'
access_token_secret = 'yXb3dELXjeqpzOzY8qjA3Lcee0MeN03LhbxheRquYpTpl'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAOh%2BuQEAAAAAwNaepY8ytq6uKbfs6LTgMog2w5A%3Dlu7HcgOWr6Wz85AEai57mtUl9sd0xJTjUR1jpi2pJyfyjSvWb4'  # Needed for API v2

# Authenticate to the API using bearer token
client = tweepy.Client(bearer_token=bearer_token)

# Define the keyword and number of tweets to search
keyword = 'Python'
num_tweets = 100

# Search for tweets containing the keyword
query = f'{keyword} -is:retweet lang:en'
tweets = client.search_recent_tweets(query=query, tweet_fields=['created_at', 'author_id', 'text'], max_results=num_tweets)

# Create a list to store tweet details
tweets_list = [[tweet.created_at, tweet.author_id, tweet.text] for tweet in tweets.data]

# Create a DataFrame from the list
df = pd.DataFrame(tweets_list, columns=['Datetime', 'AuthorID', 'Tweet'])

# Print the DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv('tweets.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[3], line 20
#      18 # Search for tweets containing the keyword
#      19 query = f'{keyword} -is:retweet lang:en'
# ---> 20 tweets = client.search_recent_tweets(query=query, tweet_fields=['created_at', 'author_id', 'text'], max_results=num_tweets)
#      22 # Create a list to store tweet details
#      23 tweets_list = [[tweet.created_at, tweet.author_id, tweet.text] for tweet in tweets.data]
#
# File /opt/conda/lib/python3.11/site-packages/tweepy/client.py:1266, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1174 """search_recent_tweets( \
#    1175     query, *, end_time=None, expansions=None, max_results=None, \
#    1176     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1263 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1264 """
# ...
