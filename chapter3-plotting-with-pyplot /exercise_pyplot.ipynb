# %% [markdown]
# ## NCERT QUESTIONS

# %% [markdown]
# Plot the following data using line plot.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as pl 
Day = [1,2,3,4,5,6,7] 
Ti
