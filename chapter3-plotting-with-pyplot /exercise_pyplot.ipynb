# %% [markdown]
# ## NCERT QUESTIONS

# %% [markdown]
# Plot the following data using line plot.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as pl 
Day = [1,2,3,4,5,6,7] 
Ticketssold = [2000,2800,3000,2500,2300,2500,1000] 
pl.title('Ticket collection') 
pl.plot(Day, Ticketssold, color = 'c') 
pl.xticks(Day, ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']) 
pl.xlabel('Days') 
pl.ylabel('Tickets Sold') 
pl.show()

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as pl 
Week1 = [5000,6000,6500,3500,4000,5500,8000] 
Week2 = [4000,3000,5000,5500,3000,4500,5500] 
Week3 = [4000,5800,3500,2500,3000,5000,5900] 
c = (Week1, Week2, Week3) 
Day = [0,1,2,3,4,5,6] # This was the thing to be tweaked.
d = pd.DataFrame(c, index = [1,2,3]) 
# print(d.T) 
d.T.plot(kind = 'bar', width = 0.8) 
pl.legend(loc = 'upper left') 
pl.title('Mela Sales Report') 
pl.xticks(Day,['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
pl.xlabel('Days') 
pl.ylabel('Sales in Rs.') 
pl.savefig('Sales.jpg',pad_inches=2.0)
pl.show()

# %%
s = {1:[5000,6000,6500,3500,4000,5500,8000], 2:[4000,3000,5000,5500,3000,4500,5500], 3:[4000,5800,3500,2500,3000,5000,5900]} 
f = pd.DataFrame(s) 
# print(f) 
Day = [0,1,2,3,4,5,6]
f.plot(kind = 'bar', width = 0.8) 
pl.legend(loc = 'upper left') 
pl.title('Mela Sales Report') 
pl.xticks(Day,['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
pl.xlabel('Days') 
pl.ylabel('Sales in Rs.') 
pl.show() 
f.to_csv('./sales.csv', sep = ',' , header = False, index = False)

# %%
import pandas as pd 
import matplotlib.pyplot as pl 
cdf = pd.read_csv('./courses.csv', names = ['Streams','Courses']) 
cdf.plot(x = 'Streams', y = 'Courses', ylabel = 'No. of Courses', kind = 'bar', color = 'c') 
pl.title('University Streams vs Courses') 
pl.show()

# %% [markdown]
# 2: Collect and store data related to the screen time of students in your class seperately for boys anf girls and present it using boxplot

# %%
import matplotlib.pyplot as pl 
girls = [10.0,9.5,13.6,12,12,10,6,4,4,8,7.3,8.2] 
boys = [12.2,8.5,17.4,11.5,12.5,12,5,8.5,6,9.2,6.3,6.2] 
pl.boxplot([girls,boys], tick_labels = ['Girls','Boys']) 
pl.ylabel('Screen Time') 
pl.title('Teenagers Screen Time') 
pl.show()

# %%
import matplotlib.pyplot as pl 
streams = ['Civil','Electrical','Mechannics','Chemical','CS'] 
adm = [15,35,40,20,50]   
pl.title('Administration Streamwise')  
pl.axis('equal')      
expl = [0,0,0,0,0.2]    
pl.pie(adm, labels = streams, explode = expl, autopct = '%5.1f%%')  
pl.savefig(pl.py)
pl.show()
